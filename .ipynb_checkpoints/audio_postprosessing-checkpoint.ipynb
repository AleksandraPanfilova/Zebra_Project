# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import soundfile as sf
from playsound import playsound

# %%
playsound('zebra audio sample_Bing_413/all/84002.01.whinnie.trim.wav')

# %%
# calculate stft
A_whinnie,_ = librosa.load('zebra audio sample_Bing_413/all/84002.01.whinnie.trim.wav')

# %%
def plot_spectrogram(Y,
                     #sr, 
                     #hop_length, 
                     y_axis="linear"
                    ):
    plt.figure(figsize=(25, 10))
    librosa.display.specshow(Y, 
                             #sr=sr, 
                             #hop_length=hop_length, 
                             x_axis="time",
                             y_axis=y_axis
                            )
    plt.colorbar(format="%+2.f")

# %%
n = len(A_whinnie)
n_fft = 2048
A_whinnie_pad = librosa.util.fix_length(A_whinnie, size=n + n_fft // 2)

# %%
stft_A_whinnie = np.abs(librosa.stft(A_whinnie_pad))
#stft_A_whinnie = np.abs(librosa.stft(A_whinnie_np))

# %%
stft_A_whinnie = librosa.amplitude_to_db(stft_A_whinnie)

# %%
plot_spectrogram(stft_A_whinnie)

# %%
# db to amplitude
stft_A_whinnie_am = librosa.db_to_amplitude(stft_A_whinnie, ref=10)

# %%
#istft
istft_A_whinnie = librosa.istft(stft_A_whinnie_am, length=n)

# %%
istft_A_whinnie
# Out:
# array([ 2.8102142e-03,  1.4000230e-03,  7.1643815e-05, ...,
#        -8.7741511e-03, -8.1632668e-03, -6.3302759e-03], dtype=float32)

# %%
sf.write('L:/Copenhagen/4_learn/Courses/7. Applied Machine Learning/Zebra_Project/zebra audio sample_Bing_413/all/84002.01.whinnie.trim_istft.wav',
        istft_A_whinnie,
        22050)

# %%
playsound('L:/Copenhagen/4_learn/Courses/7. Applied Machine Learning/Zebra_Project/zebra audio sample_Bing_413/all/84002.01.whinnie.trim_istft.wav')
